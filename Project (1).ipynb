# %%
import cv2
from ultralytics import YOLO
import json
import time

main_model = YOLO("yolov8n.pt")
sub_model = YOLO("yolov8n.pt")

def detect_objects(frame, model):
    results = model(frame)
    return results

def detect_subobjects(frame, main_bboxes):
    sub_detections = []
    for bbox in main_bboxes:
        x1, y1, x2, y2 = bbox
        cropped_frame = frame[y1:y2, x1:x2]
        results = detect_objects(cropped_frame, sub_model)
        sub_detections.append(results)
    return sub_detections


def format_to_json(main_detections, sub_detections):
    output = []
    for i, (main_obj, sub_objs) in enumerate(zip(main_detections[0].boxes, sub_detections)):
        main_json = {
            "object": main_detections[0].names[int(main_obj.cls[0])],
            "id": i,
            "bbox": main_obj.xyxy[0].tolist(),
            "subobject": []
        }

        for j, sub_obj_res in enumerate(sub_objs):
            if len(sub_obj_res) > 0 and len(sub_obj_res[0].boxes) > 0:
                for sub_obj in sub_obj_res[0].boxes:
                    sub_json = {
                        "object": sub_obj_res[0].names[int(sub_obj.cls[0])],
                        "id": j,
                        "bbox": sub_obj.xyxy[0].tolist()
                    }
                    main_json["subobject"].append(sub_json)
            else:
                sub_json = {
                    "object": "None",
                    "id": j,
                    "bbox": []
                }
                main_json["subobject"].append(sub_json)

        output.append(main_json)
    return json.dumps(output, indent=4)

def main(video_path):
    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    start_time = time.time()

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        main_results = detect_objects(frame, main_model)
        main_results = main_model(frame)

        main_bboxes = []
        for box in main_results[0].boxes:
          x1, y1, x2, y2 = map(int, box.xyxy[0])
          main_bboxes.append([x1, y1, x2, y2])

        sub_results = detect_subobjects(frame, main_bboxes)
        output_json = format_to_json(main_results, sub_results)
        print(output_json)

        frame_count += 1
    fps = frame_count / (time.time() - start_time)
    print(f"Inference Speed: {fps:.2f} FPS")

    cap.release()

if __name__ == "__main__":
    main("Chandu.mp4")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 111MB/s]
# Streaming output truncated to the last 5000 lines.
#         "object": "motorcycle",
#         "id": 0,
#         "bbox": [
#             0.0,
#             171.2018585205078,
#             734.3135375976562,
#             519.25927734375
#         ],
#         "subobject": [
#             {
#                 "object": "motorcycle",
#                 "id": 0,
#                 "bbox": [
#                     361.4631652832031,
#                     20.364730834960938,
#                     729.36572265625,
#                     344.0994567871094
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 motorcycle, 193.0ms
# Speed: 3.6ms preprocess, 193.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 193.0ms
# Speed: 3.7ms preprocess, 193.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 357.5ms
# Speed: 4.4ms preprocess, 357.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# [
#     {
#         "object": "motorcycle",
#         "id": 0,
#         "bbox": [
#             414.3875427246094,
#             177.0926513671875,
#             764.345458984375,
#             518.0414428710938
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 motorcycle, 201.2ms
# Speed: 3.9ms preprocess, 201.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 199.1ms
# Speed: 3.6ms preprocess, 199.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 1 motorcycle, 343.6ms
# Speed: 4.9ms preprocess, 343.6ms inference, 2.0ms postprocess per image at shape (1, 3, 608, 640)
# [
#     {
#         "object": "motorcycle",
#         "id": 0,
#         "bbox": [
#             445.8957824707031,
#             176.99368286132812,
#             807.832275390625,
#             518.830810546875
#         ],
#         "subobject": [
#             {
#                 "object": "motorcycle",
#                 "id": 0,
#                 "bbox": [
#                     6.604700565338135,
#                     3.5222792625427246,
#                     358.7857971191406,
#                     322.93878173828125
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 motorcycle, 230.2ms
# Speed: 4.6ms preprocess, 230.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 217.5ms
# Speed: 4.2ms preprocess, 217.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 motorcycle, 339.5ms
# Speed: 4.8ms preprocess, 339.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# [
#     {
#         "object": "motorcycle",
#         "id": 0,
#         "bbox": [
#             494.7117919921875,
#             177.7108154296875,
#             850.1032104492188,
#             519.4358520507812
#         ],
#         "subobject": [
#             {
#                 "object": "motorcycle",
#                 "id": 0,
#                 "bbox": [
#                     13.10820198059082,
#                     9.738142967224121,
#                     354.31488037109375,
#                     286.4453125
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 motorcycle, 207.0ms
# Speed: 4.1ms preprocess, 207.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 138.3ms
# Speed: 4.7ms preprocess, 138.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 motorcycle, 1 scissors, 230.9ms
# Speed: 4.3ms preprocess, 230.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# [
#     {
#         "object": "motorcycle",
#         "id": 0,
#         "bbox": [
#             549.587646484375,
#             177.48756408691406,
#             896.3228759765625,
#             519.611572265625
#         ],
#         "subobject": [
#             {
#                 "object": "motorcycle",
#                 "id": 0,
#                 "bbox": [
#                     2.8620047569274902,
#                     3.801269292831421,
#                     345.01092529296875,
#                     282.1816711425781
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 car, 1 motorcycle, 1 airplane, 141.7ms
# Speed: 3.8ms preprocess, 141.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 motorcycle, 1 airplane, 137.1ms
# Speed: 3.8ms preprocess, 137.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 motorcycle, 233.9ms
# Speed: 4.5ms preprocess, 233.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 182.2ms
# Speed: 5.1ms preprocess, 182.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 224x640 1 car, 1 motorcycle, 1 airplane, 85.7ms
# Speed: 3.7ms preprocess, 85.7ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 640)
# [
#     {
#         "object": "motorcycle",
#         "id": 0,
#         "bbox": [
#             634.8622436523438,
#             184.44776916503906,
#             959.6688232421875,
#             518.4392700195312
#         ],
#         "subobject": [
#             {
#                 "object": "motorcycle",
#                 "id": 0,
#                 "bbox": [
#                     9.312143325805664,
#                     5.3880791664123535,
#                     325.0,
#                     273.9324035644531
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "car",
#         "id": 1,
#         "bbox": [
#             0.72271728515625,
#             199.5450897216797,
#             357.6850891113281,
#             456.3570861816406
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 2,
#         "bbox": [
#             0.0,
#             179.63868713378906,
#             952.0925903320312,
#             475.2689514160156
#         ],
#         "subobject": [
#             {
#                 "object": "motorcycle",
#                 "id": 0,
#                 "bbox": [
#                     626.39697265625,
#                     5.169979095458984,
#                     951.2184448242188,
#                     296.0
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 person, 1 car, 1 motorcycle, 1 airplane, 146.5ms
# Speed: 4.1ms preprocess, 146.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 motorcycle, 1 airplane, 133.3ms
# Speed: 4.6ms preprocess, 133.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 172.4ms
# Speed: 3.7ms preprocess, 172.4ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x640 (no detections), 231.1ms
# Speed: 5.0ms preprocess, 231.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 motorcycle, 197.7ms
# Speed: 4.1ms preprocess, 197.7ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 192x640 1 motorcycle, 1 airplane, 86.7ms
# Speed: 2.0ms preprocess, 86.7ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# [
#     {
#         "object": "car",
#         "id": 0,
#         "bbox": [
#             0.8015213012695312,
#             202.33099365234375,
#             321.07781982421875,
#             457.8132019042969
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "motorcycle",
#         "id": 1,
#         "bbox": [
#             662.7901611328125,
#             214.17013549804688,
#             959.4715576171875,
#             520.3185424804688
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "person",
#         "id": 2,
#         "bbox": [
#             706.5452270507812,
#             173.8000946044922,
#             959.5332641601562,
#             388.39483642578125
#         ],
#         "subobject": [
#             {
#                 "object": "motorcycle",
#                 "id": 0,
#                 "bbox": [
#                     0.3640909194946289,
#                     0.49886971712112427,
#                     248.0313262939453,
#                     215.0
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 3,
#         "bbox": [
#             0.093658447265625,
#             184.11172485351562,
#             945.4341430664062,
#             464.3169250488281
#         ],
#         "subobject": [
#             {
#                 "object": "motorcycle",
#                 "id": 0,
#                 "bbox": [
#                     662.06201171875,
#                     0.0624997653067112,
#                     944.5046997070312,
#                     280.0
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 motorcycle, 3 airplanes, 139.1ms
# Speed: 3.7ms preprocess, 139.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 3 airplanes, 136.4ms
# Speed: 3.8ms preprocess, 136.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 1 person, 1 motorcycle, 1 airplane, 99.3ms
# Speed: 3.2ms preprocess, 99.3ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 640x480 (no detections), 164.7ms
# Speed: 3.5ms preprocess, 164.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 (no detections), 196.6ms
# Speed: 3.8ms preprocess, 196.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 192x640 1 motorcycle, 1 airplane, 79.4ms
# Speed: 1.9ms preprocess, 79.4ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             48.117095947265625,
#             171.20901489257812,
#             958.7884521484375,
#             520.3084716796875
#         ],
#         "subobject": [
#             {
#                 "object": "motorcycle",
#                 "id": 0,
#                 "bbox": [
#                     654.1458740234375,
#                     37.665367126464844,
#                     909.2533569335938,
#                     345.771728515625
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 1,
#         "bbox": [
#             702.8199462890625,
#             174.2427978515625,
#             959.61767578125,
#             518.8204345703125
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "motorcycle",
#         "id": 2,
#         "bbox": [
#             703.06201171875,
#             173.87100219726562,
#             959.5215454101562,
#             519.5604858398438
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 3,
#         "bbox": [
#             0.63812255859375,
#             194.4965057373047,
#             915.5187377929688,
#             460.17938232421875
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     37.49064254760742,
#                     0.3335123062133789,
#                     912.1126098632812,
#                     266.0
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 person, 1 motorcycle, 1 airplane, 139.4ms
# Speed: 5.0ms preprocess, 139.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 motorcycle, 1 airplane, 134.4ms
# Speed: 4.8ms preprocess, 134.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x480 1 motorcycle, 168.2ms
# Speed: 4.1ms preprocess, 168.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 192x640 1 airplane, 76.7ms
# Speed: 2.2ms preprocess, 76.7ms inference, 1.1ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 640x480 (no detections), 179.3ms
# Speed: 3.8ms preprocess, 179.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# [
#     {
#         "object": "person",
#         "id": 0,
#         "bbox": [
#             780.24755859375,
#             171.82498168945312,
#             959.445556640625,
#             417.99481201171875
#         ],
#         "subobject": [
#             {
#                 "object": "motorcycle",
#                 "id": 0,
#                 "bbox": [
#                     2.324643135070801,
#                     1.7482916116714478,
#                     179.0,
#                     243.43292236328125
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 1,
#         "bbox": [
#             1.279815673828125,
#             215.25906372070312,
#             875.8465576171875,
#             459.2128601074219
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     2.7461698055267334,
#                     48.768707275390625,
#                     824.1718139648438,
#                     237.43797302246094
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "motorcycle",
#         "id": 2,
#         "bbox": [
#             744.5909423828125,
#             213.4276885986328,
#             959.4360961914062,
#             519.5012817382812
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 person, 1 motorcycle, 2 airplanes, 160.3ms
# Speed: 3.9ms preprocess, 160.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 motorcycle, 2 airplanes, 134.8ms
# Speed: 4.5ms preprocess, 134.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x384 (no detections), 149.9ms
# Speed: 4.0ms preprocess, 149.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 192x640 1 airplane, 75.6ms
# Speed: 1.9ms preprocess, 75.6ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 640x448 (no detections), 156.2ms
# Speed: 3.2ms preprocess, 156.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 256x640 1 person, 2 airplanes, 95.2ms
# Speed: 3.4ms preprocess, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 640)
# [
#     {
#         "object": "person",
#         "id": 0,
#         "bbox": [
#             822.99609375,
#             171.74038696289062,
#             959.2901000976562,
#             402.7823181152344
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 1,
#         "bbox": [
#             1.29071044921875,
#             234.58753967285156,
#             883.7398681640625,
#             459.2533264160156
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     52.92877960205078,
#                     0.0,
#                     880.5963745117188,
#                     221.78073120117188
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "motorcycle",
#         "id": 2,
#         "bbox": [
#             799.3661499023438,
#             274.83929443359375,
#             959.5032348632812,
#             519.9146728515625
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 3,
#         "bbox": [
#             40.47930908203125,
#             171.00961303710938,
#             958.154296875,
#             521.4586181640625
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     27.405370712280273,
#                     2.593763828277588,
#                     917.0831298828125,
#                     347.08233642578125
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 2 airplanes, 145.2ms
# Speed: 4.2ms preprocess, 145.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 157.3ms
# Speed: 4.0ms preprocess, 157.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 1 motorcycle, 1 airplane, 100.3ms
# Speed: 2.6ms preprocess, 100.3ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 160x640 (no detections), 76.6ms
# Speed: 2.1ms preprocess, 76.6ms inference, 0.7ms postprocess per image at shape (1, 3, 160, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             67.00039672851562,
#             170.22967529296875,
#             959.2134399414062,
#             522.0054931640625
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     21.689895629882812,
#                     0.7787101864814758,
#                     892.0,
#                     347.94049072265625
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 1,
#         "bbox": [
#             0.365478515625,
#             272.666748046875,
#             775.446533203125,
#             455.3024597167969
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 car, 1 airplane, 135.4ms
# Speed: 7.7ms preprocess, 135.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 138.8ms
# Speed: 4.0ms preprocess, 138.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 128x640 (no detections), 66.9ms
# Speed: 1.8ms preprocess, 66.9ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 640x160 (no detections), 92.9ms
# Speed: 1.5ms preprocess, 92.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 160)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             1.767791748046875,
#             287.4138488769531,
#             827.716552734375,
#             448.84149169921875
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "car",
#         "id": 1,
#         "bbox": [
#             879.9210205078125,
#             176.30941772460938,
#             959.7301025390625,
#             518.4867553710938
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 car, 2 airplanes, 152.8ms
# Speed: 4.2ms preprocess, 152.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 airplanes, 151.0ms
# Speed: 3.7ms preprocess, 151.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 192x640 1 car, 1 airplane, 87.0ms
# Speed: 2.6ms preprocess, 87.0ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 640x512 (no detections), 173.9ms
# Speed: 6.9ms preprocess, 173.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 128x640 (no detections), 56.3ms
# Speed: 1.8ms preprocess, 56.3ms inference, 0.5ms postprocess per image at shape (1, 3, 128, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             13.345733642578125,
#             217.74449157714844,
#             960.0,
#             494.87548828125
#         ],
#         "subobject": [
#             {
#                 "object": "car",
#                 "id": 0,
#                 "bbox": [
#                     732.436279296875,
#                     26.141176223754883,
#                     946.6123657226562,
#                     277.0
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "car",
#         "id": 1,
#         "bbox": [
#             745.5126342773438,
#             237.47227478027344,
#             959.6339721679688,
#             510.4403076171875
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 2,
#         "bbox": [
#             1.6376953125,
#             292.4373474121094,
#             841.791748046875,
#             448.8570556640625
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     }
# ]
#
# 0: 384x640 2 airplanes, 137.0ms
# Speed: 4.6ms preprocess, 137.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 133.5ms
# Speed: 3.8ms preprocess, 133.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 233.8ms
# Speed: 4.2ms preprocess, 233.8ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 192x640 1 airplane, 80.1ms
# Speed: 2.1ms preprocess, 80.1ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             700.4039306640625,
#             228.34689331054688,
#             959.3504028320312,
#             468.73516845703125
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 1,
#         "bbox": [
#             6.8529052734375,
#             193.38331604003906,
#             957.2369384765625,
#             471.878662109375
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     7.706940174102783,
#                     1.516093373298645,
#                     948.195068359375,
#                     267.1692810058594
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 2 airplanes, 144.8ms
# Speed: 3.8ms preprocess, 144.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 139.9ms
# Speed: 4.0ms preprocess, 139.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 192x640 1 airplane, 75.9ms
# Speed: 2.0ms preprocess, 75.9ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 480x640 (no detections), 163.7ms
# Speed: 3.4ms preprocess, 163.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             15.5789794921875,
#             206.6813507080078,
#             958.276611328125,
#             474.4303894042969
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     13.90727424621582,
#                     21.963741302490234,
#                     940.8602294921875,
#                     262.1483459472656
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 1,
#         "bbox": [
#             649.6014404296875,
#             228.2757110595703,
#             959.4180908203125,
#             458.01068115234375
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     }
# ]
#
# 0: 384x640 2 airplanes, 131.7ms
# Speed: 3.7ms preprocess, 131.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 154.4ms
# Speed: 4.0ms preprocess, 154.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 224x640 2 airplanes, 88.7ms
# Speed: 2.2ms preprocess, 88.7ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 416x640 1 mouse, 151.2ms
# Speed: 3.3ms preprocess, 151.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             2.58837890625,
#             183.02320861816406,
#             958.9458618164062,
#             471.47900390625
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     7.852034091949463,
#                     12.775053977966309,
#                     952.8436279296875,
#                     288.0
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 1,
#         "bbox": [
#             553.8640747070312,
#             195.72523498535156,
#             959.1229248046875,
#             457.9708557128906
#         ],
#         "subobject": [
#             {
#                 "object": "mouse",
#                 "id": 0,
#                 "bbox": [
#                     68.28351593017578,
#                     154.4487762451172,
#                     206.0328826904297,
#                     244.09262084960938
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 car, 3 airplanes, 143.1ms
# Speed: 3.6ms preprocess, 143.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 airplanes, 134.6ms
# Speed: 4.8ms preprocess, 134.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 143.0ms
# Speed: 4.7ms preprocess, 143.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 192x640 1 airplane, 79.0ms
# Speed: 2.1ms preprocess, 79.0ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 352x640 (no detections), 143.1ms
# Speed: 3.3ms preprocess, 143.1ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 288x640 3 airplanes, 105.1ms
# Speed: 2.9ms preprocess, 105.1ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             501.978515625,
#             200.2689971923828,
#             959.4569702148438,
#             458.0246887207031
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 1,
#         "bbox": [
#             2.6033935546875,
#             190.01211547851562,
#             959.9672241210938,
#             469.33477783203125
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     3.0609002113342285,
#                     11.063386917114258,
#                     955.63720703125,
#                     274.5212097167969
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "car",
#         "id": 2,
#         "bbox": [
#             504.44073486328125,
#             225.911865234375,
#             958.94677734375,
#             454.5958557128906
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 3,
#         "bbox": [
#             0.0,
#             74.50350952148438,
#             958.7217407226562,
#             480.3170471191406
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     0.0,
#                     125.66423034667969,
#                     958.0,
#                     397.9577941894531
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 3 airplanes, 143.2ms
# Speed: 4.2ms preprocess, 143.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 airplanes, 140.2ms
# Speed: 4.1ms preprocess, 140.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 (no detections), 114.3ms
# Speed: 2.9ms preprocess, 114.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 192x640 (no detections), 79.1ms
# Speed: 2.1ms preprocess, 79.1ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 288x640 3 airplanes, 106.0ms
# Speed: 3.5ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             454.517578125,
#             218.7981719970703,
#             959.0885009765625,
#             455.65155029296875
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 1,
#         "bbox": [
#             0.097412109375,
#             218.76104736328125,
#             958.3416748046875,
#             470.4908752441406
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 2,
#         "bbox": [
#             0.0,
#             71.25137329101562,
#             959.0831909179688,
#             474.41802978515625
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     454.2437744140625,
#                     119.51995849609375,
#                     958.41015625,
#                     382.0787658691406
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 car, 2 airplanes, 136.0ms
# Speed: 4.3ms preprocess, 136.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 airplanes, 214.4ms
# Speed: 3.6ms preprocess, 214.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 160x640 1 car, 97.7ms
# Speed: 1.8ms preprocess, 97.7ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 640)
#
# 0: 288x640 3 airplanes, 177.2ms
# Speed: 2.6ms preprocess, 177.2ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 (no detections), 147.2ms
# Speed: 2.4ms preprocess, 147.2ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             1.75927734375,
#             226.77818298339844,
#             958.8740844726562,
#             465.89239501953125
#         ],
#         "subobject": [
#             {
#                 "object": "car",
#                 "id": 0,
#                 "bbox": [
#                     404.3130798339844,
#                     1.1702207326889038,
#                     955.5811767578125,
#                     236.27853393554688
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 1,
#         "bbox": [
#             1.181396484375,
#             70.56788635253906,
#             956.4135131835938,
#             473.0711975097656
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     0.0,
#                     13.77400016784668,
#                     954.7898559570312,
#                     400.2345886230469
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "car",
#         "id": 2,
#         "bbox": [
#             408.9609375,
#             227.08250427246094,
#             959.5482788085938,
#             456.3442687988281
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     }
# ]
#
# 0: 384x640 2 airplanes, 209.8ms
# Speed: 5.5ms preprocess, 209.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 218.4ms
# Speed: 6.6ms preprocess, 218.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 192x640 1 person, 106.1ms
# Speed: 2.2ms preprocess, 106.1ms inference, 1.2ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 288x640 1 person, 2 airplanes, 153.3ms
# Speed: 2.8ms preprocess, 153.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             1.72357177734375,
#             224.42120361328125,
#             957.047119140625,
#             471.4329528808594
#         ],
#         "subobject": [
#             {
#                 "object": "person",
#                 "id": 0,
#                 "bbox": [
#                     883.7810668945312,
#                     121.2234115600586,
#                     955.5682373046875,
#                     238.72767639160156
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 1,
#         "bbox": [
#             0.0,
#             75.04220581054688,
#             956.9602661132812,
#             471.885498046875
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     1.3510669469833374,
#                     146.64830017089844,
#                     956.0,
#                     392.5357971191406
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 airplane, 204.2ms
# Speed: 4.5ms preprocess, 204.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 194.5ms
# Speed: 3.7ms preprocess, 194.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 (no detections), 183.1ms
# Speed: 3.7ms preprocess, 183.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             270.65606689453125,
#             87.65357971191406,
#             959.7293701171875,
#             462.5415344238281
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 car, 1 airplane, 211.0ms
# Speed: 6.7ms preprocess, 211.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 208.9ms
# Speed: 3.6ms preprocess, 208.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 (no detections), 184.6ms
# Speed: 2.9ms preprocess, 184.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 224x640 (no detections), 123.6ms
# Speed: 4.9ms preprocess, 123.6ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             219.87100219726562,
#             85.43692016601562,
#             959.987548828125,
#             454.6608581542969
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "car",
#         "id": 1,
#         "bbox": [
#             219.54830932617188,
#             224.4304962158203,
#             959.248046875,
#             454.59039306640625
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     }
# ]
#
# 0: 384x640 2 airplanes, 251.0ms
# Speed: 3.7ms preprocess, 251.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 212.7ms
# Speed: 3.7ms preprocess, 212.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 person, 169.9ms
# Speed: 2.8ms preprocess, 169.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 224x640 1 person, 100.3ms
# Speed: 2.1ms preprocess, 100.3ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             179.72479248046875,
#             85.13603210449219,
#             958.232666015625,
#             459.9967346191406
#         ],
#         "subobject": [
#             {
#                 "object": "person",
#                 "id": 0,
#                 "bbox": [
#                     517.494140625,
#                     261.3861083984375,
#                     667.312744140625,
#                     367.3506774902344
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 1,
#         "bbox": [
#             180.48257446289062,
#             220.18148803710938,
#             959.634765625,
#             455.9297180175781
#         ],
#         "subobject": [
#             {
#                 "object": "person",
#                 "id": 0,
#                 "bbox": [
#                     516.73486328125,
#                     126.07257080078125,
#                     676.1287841796875,
#                     235.0
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 2 airplanes, 134.7ms
# Speed: 3.9ms preprocess, 134.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 135.1ms
# Speed: 4.0ms preprocess, 135.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 person, 129.6ms
# Speed: 3.7ms preprocess, 129.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 192x640 (no detections), 78.0ms
# Speed: 1.9ms preprocess, 78.0ms inference, 0.6ms postprocess per image at shape (1, 3, 192, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             129.964599609375,
#             84.94538116455078,
#             960.0,
#             459.5552673339844
#         ],
#         "subobject": [
#             {
#                 "object": "person",
#                 "id": 0,
#                 "bbox": [
#                     521.1773681640625,
#                     263.39813232421875,
#                     669.9845581054688,
#                     375.0
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 1,
#         "bbox": [
#             136.01129150390625,
#             219.1468505859375,
#             960.0,
#             453.3498229980469
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 airplane, 136.0ms
# Speed: 4.4ms preprocess, 136.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 141.0ms
# Speed: 3.7ms preprocess, 141.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 (no detections), 133.6ms
# Speed: 2.9ms preprocess, 133.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             63.706695556640625,
#             83.46359252929688,
#             956.9118041992188,
#             488.1822814941406
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     }
# ]
#
# 0: 384x640 2 airplanes, 149.2ms
# Speed: 3.6ms preprocess, 149.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 131.8ms
# Speed: 3.7ms preprocess, 131.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 (no detections), 127.6ms
# Speed: 2.7ms preprocess, 127.6ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 160x640 1 train, 65.6ms
# Speed: 2.1ms preprocess, 65.6ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             5.105438232421875,
#             80.3389892578125,
#             959.8306274414062,
#             473.22088623046875
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 1,
#         "bbox": [
#             0.0,
#             227.5448455810547,
#             957.2810668945312,
#             457.9668273925781
#         ],
#         "subobject": [
#             {
#                 "object": "train",
#                 "id": 0,
#                 "bbox": [
#                     5.898197174072266,
#                     3.1490638256073,
#                     952.3699951171875,
#                     230.0
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 airplane, 134.4ms
# Speed: 4.2ms preprocess, 134.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 136.5ms
# Speed: 3.6ms preprocess, 136.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 2 airplanes, 114.4ms
# Speed: 3.2ms preprocess, 114.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             4.92755126953125,
#             75.67158508300781,
#             958.8158569335938,
#             481.7613830566406
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     0.6751665472984314,
#                     153.04995727539062,
#                     953.6040649414062,
#                     406.0
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 airplane, 148.6ms
# Speed: 4.0ms preprocess, 148.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 132.7ms
# Speed: 4.3ms preprocess, 132.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 airplane, 115.2ms
# Speed: 3.0ms preprocess, 115.2ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             0.0,
#             72.92216491699219,
#             957.439453125,
#             462.7094421386719
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     1.717090368270874,
#                     155.71908569335938,
#                     954.4425048828125,
#                     390.0
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 airplane, 152.1ms
# Speed: 4.6ms preprocess, 152.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 139.5ms
# Speed: 4.1ms preprocess, 139.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 160x640 (no detections), 63.4ms
# Speed: 1.8ms preprocess, 63.4ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             1.310760498046875,
#             224.13880920410156,
#             953.2203369140625,
#             453.19976806640625
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     }
# ]
#
# 0: 384x640 2 airplanes, 137.4ms
# Speed: 3.7ms preprocess, 137.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 136.9ms
# Speed: 3.7ms preprocess, 136.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 160x640 1 airplane, 82.0ms
# Speed: 2.1ms preprocess, 82.0ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 640)
#
# 0: 288x640 (no detections), 110.3ms
# Speed: 3.0ms preprocess, 110.3ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             0.9261474609375,
#             218.5081787109375,
#             957.1950073242188,
#             456.51507568359375
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     0.27261343598365784,
#                     5.1832146644592285,
#                     953.407470703125,
#                     238.0
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 1,
#         "bbox": [
#             0.0,
#             73.1407470703125,
#             958.547607421875,
#             460.3451843261719
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     }
# ]
#
# 0: 384x640 2 airplanes, 159.4ms
# Speed: 3.6ms preprocess, 159.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 131.7ms
# Speed: 3.7ms preprocess, 131.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 192x640 1 person, 80.3ms
# Speed: 2.7ms preprocess, 80.3ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 288x640 1 airplane, 110.0ms
# Speed: 3.9ms preprocess, 110.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             0.0,
#             212.2609405517578,
#             957.26171875,
#             455.3722229003906
#         ],
#         "subobject": [
#             {
#                 "object": "person",
#                 "id": 0,
#                 "bbox": [
#                     268.9992980957031,
#                     134.1333465576172,
#                     414.14990234375,
#                     241.8008575439453
#                 ]
#             }
#         ]
#     },
#     {
#         "object": "airplane",
#         "id": 1,
#         "bbox": [
#             0.0,
#             59.9095458984375,
#             956.449951171875,
#             458.78668212890625
#         ],
#         "subobject": [
#             {
#                 "object": "airplane",
#                 "id": 0,
#                 "bbox": [
#                     0.0,
#                     17.585113525390625,
#                     952.4168090820312,
#                     395.9778137207031
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 airplane, 135.1ms
# Speed: 7.7ms preprocess, 135.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 136.0ms
# Speed: 4.3ms preprocess, 136.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 192x640 (no detections), 89.8ms
# Speed: 2.0ms preprocess, 89.8ms inference, 0.6ms postprocess per image at shape (1, 3, 192, 640)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             0.066650390625,
#             200.7322998046875,
#             950.545166015625,
#             456.95654296875
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     }
# ]
#
# 0: 384x640 2 airplanes, 146.3ms
# Speed: 4.6ms preprocess, 146.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 138.8ms
# Speed: 5.5ms preprocess, 138.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 288x640 1 airplane, 110.9ms
# Speed: 3.9ms preprocess, 110.9ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 640x160 (no detections), 80.9ms
# Speed: 1.5ms preprocess, 80.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 160)
# [
#     {
#         "object": "airplane",
#         "id": 0,
#         "bbox": [
#             156.79522705078125,
#             171.17779541015625,
#             959.3763427734375,
#             518.04296875
#         ],
#         "subobject": [
#             {
# ...
#                     119.65428161621094,
#                     170.87237548828125,
#                     228.8760528564453
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 person, 1 motorcycle, 138.4ms
# Speed: 5.3ms preprocess, 138.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 motorcycle, 136.4ms
# Speed: 5.0ms preprocess, 136.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 (no detections), 151.4ms
# Speed: 4.3ms preprocess, 151.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x480 1 motorcycle, 1 scissors, 166.1ms
# Speed: 3.4ms preprocess, 166.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# [
#     {
#         "object": "motorcycle",
#         "id": 0,
#         "bbox": [
#             52.12220764160156,
#             254.24452209472656,
#             410.0414733886719,
#             478.140380859375
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "person",
#         "id": 1,
#         "bbox": [
#             147.1435546875,
#             199.49267578125,
#             319.094970703125,
#             430.1664123535156
#         ],
#         "subobject": [
#             {
#                 "object": "motorcycle",
#                 "id": 0,
#                 "bbox": [
#                     0.0,
#                     2.906709909439087,
#                     171.8848419189453,
#                     230.80824279785156
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 person, 1 motorcycle, 136.2ms
# Speed: 3.8ms preprocess, 136.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 motorcycle, 147.0ms
# Speed: 3.7ms preprocess, 147.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 (no detections), 143.7ms
# Speed: 3.4ms preprocess, 143.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x480 (no detections), 168.5ms
# Speed: 3.6ms preprocess, 168.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# [
#     {
#         "object": "motorcycle",
#         "id": 0,
#         "bbox": [
#             52.180572509765625,
#             255.19692993164062,
#             410.2202453613281,
#             480.16571044921875
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "person",
#         "id": 1,
#         "bbox": [
#             148.3388214111328,
#             198.34716796875,
#             323.4300842285156,
#             432.88970947265625
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 person, 1 motorcycle, 137.1ms
# Speed: 3.9ms preprocess, 137.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 motorcycle, 136.6ms
# Speed: 3.8ms preprocess, 136.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 (no detections), 143.0ms
# Speed: 4.3ms preprocess, 143.0ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x512 1 motorcycle, 1 scissors, 189.5ms
# Speed: 4.3ms preprocess, 189.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
# [
#     {
#         "object": "motorcycle",
#         "id": 0,
#         "bbox": [
#             52.3560676574707,
#             255.68472290039062,
#             411.41656494140625,
#             478.28851318359375
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "person",
#         "id": 1,
#         "bbox": [
#             147.59523010253906,
#             198.2815704345703,
#             324.7720031738281,
#             431.0010986328125
#         ],
#         "subobject": [
#             {
#                 "object": "scissors",
#                 "id": 0,
#                 "bbox": [
#                     9.399330139160156,
#                     116.9914779663086,
#                     166.4211883544922,
#                     232.66476440429688
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 person, 1 motorcycle, 143.0ms
# Speed: 4.6ms preprocess, 143.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 motorcycle, 135.2ms
# Speed: 4.7ms preprocess, 135.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 (no detections), 155.1ms
# Speed: 4.1ms preprocess, 155.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x512 1 motorcycle, 178.7ms
# Speed: 4.4ms preprocess, 178.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
# [
#     {
#         "object": "motorcycle",
#         "id": 0,
#         "bbox": [
#             52.29881286621094,
#             256.0360412597656,
#             410.52703857421875,
#             479.3284912109375
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "person",
#         "id": 1,
#         "bbox": [
#             146.5795135498047,
#             198.26051330566406,
#             325.6192932128906,
#             429.632568359375
#         ],
#         "subobject": [
#             {
#                 "object": "motorcycle",
#                 "id": 0,
#                 "bbox": [
#                     0.0,
#                     1.8673404455184937,
#                     179.0,
#                     230.96153259277344
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 person, 1 motorcycle, 133.0ms
# Speed: 4.4ms preprocess, 133.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 motorcycle, 220.2ms
# Speed: 3.9ms preprocess, 220.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 (no detections), 213.0ms
# Speed: 3.2ms preprocess, 213.0ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x512 1 motorcycle, 278.6ms
# Speed: 3.7ms preprocess, 278.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
# [
#     {
#         "object": "motorcycle",
#         "id": 0,
#         "bbox": [
#             53.171504974365234,
#             255.6207275390625,
#             410.63922119140625,
#             479.0221252441406
#         ],
#         "subobject": [
#             {
#                 "object": "None",
#                 "id": 0,
#                 "bbox": []
#             }
#         ]
#     },
#     {
#         "object": "person",
#         "id": 1,
#         "bbox": [
#             145.7790069580078,
#             198.20301818847656,
#             321.6326599121094,
#             429.8443298339844
#         ],
#         "subobject": [
#             {
#                 "object": "motorcycle",
#                 "id": 0,
#                 "bbox": [
#                     0.0,
#                     0.0,
#                     174.25613403320312,
#                     230.3046417236328
#                 ]
#             }
#         ]
#     }
# ]
#
# 0: 384x640 1 person, 1 motorcycle, 199.7ms
# Speed: 3.9ms preprocess, 199.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 motorcycle, 205.5ms
# Speed: 3.9ms preprocess, 205.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-2091888eca23> in <cell line: 98>()
#      97
#      98 if __name__ == "__main__":
# ---> 99     main("Chandu.mp4")
#
# <ipython-input-3-2091888eca23> in main(video_path)
#      82
#      83         # Sub-object detection
# ---> 84         sub_results = detect_subobjects(frame, main_bboxes)
#      85
#      86         # JSON Formatting
#
# <ipython-input-3-2091888eca23> in detect_subobjects(frame, main_bboxes)
#      17         x1, y1, x2, y2 = bbox
#      18         cropped_frame = frame[y1:y2, x1:x2]
# ---> 19         results = detect_objects(cropped_frame, sub_model)
#      20         sub_detections.append(results)
#      21     return sub_detections
#
# <ipython-input-3-2091888eca23> in detect_objects(frame, model)
#       9
#      10 def detect_objects(frame, model):
# ---> 11     results = model(frame)
#      12     return results
#      13
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in __call__(self, source, stream, **kwargs)
#     178             ...     print(f"Detected {len(r)} objects in image")
#     179         """
# --> 180         return self.predict(source, stream, **kwargs)
#     181
#     182     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     556         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     557             self.predictor.set_prompts(prompts)
# --> 558         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     559
#     560     def track(
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     171             return self.stream_inference(source, model, *args, **kwargs)
#     172         else:
# --> 173             return list(self.stream_inference(source, model, *args, **kwargs))  # merge list of Result into one
#     174
#     175     def predict_cli(self, source=None, model=None):
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in generator_context(*args, **kwargs)
#      34             # Issuing `None` to a generator fires it up
#      35             with ctx_factory():
# ---> 36                 response = gen.send(None)
#      37
#      38             while True:
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/predictor.py in stream_inference(self, source, model, *args, **kwargs)
#     257                 # Inference
#     258                 with profilers[1]:
# --> 259                     preds = self.inference(im, *args, **kwargs)
#     260                     if self.args.embed:
#     261                         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/predictor.py in inference(self, im, *args, **kwargs)
#     141             else False
#     142         )
# --> 143         return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#     144
#     145     def pre_transform(self, im):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/autobackend.py in forward(self, im, augment, visualize, embed)
#     522         # PyTorch
#     523         if self.pt or self.nn_module:
# --> 524             y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     525
#     526         # TorchScript
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py in forward(self, x, *args, **kwargs)
#     112         if isinstance(x, dict):  # for cases of training and validating while training.
#     113             return self.loss(x, *args, **kwargs)
# --> 114         return self.predict(x, *args, **kwargs)
#     115
#     116     def predict(self, x, profile=False, visualize=False, augment=False, embed=None):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py in predict(self, x, profile, visualize, augment, embed)
#     130         if augment:
#     131             return self._predict_augment(x)
# --> 132         return self._predict_once(x, profile, visualize, embed)
#     133
#     134     def _predict_once(self, x, profile=False, visualize=False, embed=None):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py in _predict_once(self, x, profile, visualize, embed)
#     151             if profile:
#     152                 self._profile_one_layer(m, x, dt)
# --> 153             x = m(x)  # run
#     154             y.append(x if m.i in self.save else None)  # save output
#     155             if visualize:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/modules/conv.py in forward_fuse(self, x)
#      53     def forward_fuse(self, x):
#      54         """Apply convolution and activation without batch normalization."""
# ---> 55         return self.act(self.conv(x))
#      56
#      57
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     552
#     553     def forward(self, input: Tensor) -> Tensor:
# --> 554         return self._conv_forward(input, self.weight, self.bias)
#     555
#     556
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     547                 self.groups,
#     548             )
# --> 549         return F.conv2d(
#     550             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551         )
#
# KeyboardInterrupt:
